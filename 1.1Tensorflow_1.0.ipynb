# %% [markdown]
# # Week 1

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.5.0-dev20201106'

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train/255
y_test = x_test/255

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5, batch_size=32)
# Out:
# ...
# 11493376/11490434 [==============================] - 1s 0us/step
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4890 - accuracy: 0.8589
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1545 - accuracy: 0.9527
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1119 - accuracy: 0.9672
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0846 - accuracy: 0.9738
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0752 - accuracy: 0.9754

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
k = r'C:\Users\44788/Desktop\initial.png'
Image.open(k)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=945x387 at 0x28407195848>

# %% [raw]
# whats changed?
# define placeholder(to feed data into) and vairables, so that everything is in place before you can actually run your model
# these operations define a computational graph which explains how inputs, outputs and parameters of the model are all connected.
# once the graph is built you would need to run it by initlaising a session and also initlaize the variables
# then train the model by passing in the data (with the feed dict) and calcualting the loss
#
# tensorflow 2 does a away with a lot of this
#
# eager execution - no need to run an intializer or a session as all varuiables are ready and values accessible
# keras has become the high level API as a wrapper for tensorflow
# keras is easy to use but also very flexible
# API cleanup
